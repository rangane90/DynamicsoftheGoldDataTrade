# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Import the data file

# %%
import pandas as pd

# Try different encodings until the file is read successfully
encodings = ['latin-1', 'cp1252']  # Examples, replace with likely encodings for your data
for encoding in encodings:
  try:
    df = pd.read_csv("E://Studies//DS&B//DATA//final.csv", encoding=encoding)
    break  # If successful, break out of the loop
  except UnicodeDecodeError:
    pass  # If there's an error, continue trying other encodings

# Handle cases where no encoding works (add checks or error handling here)
if 'df' not in locals():
  print("Couldn't find a suitable encoding for the file.")

# %% [markdown]
# Data Information

# %%
df.shape
# Out:
# (1819, 47)

# %%
df.describe()
# Out:
#         RefPeriodId      RefYear     RefMonth         Period  ReporterCode  \
# count  1.819000e+03  1819.000000  1819.000000    1819.000000   1819.000000
# mean   2.020407e+07  2020.341946     7.373282  198747.422760    791.939527
# std    1.880385e+04     1.878210     6.725219   25483.411566     58.722321
# min    2.017010e+07  2017.000000     1.000000    2017.000000    710.000000
# 25%    2.019040e+07  2019.000000     4.000000  201904.000000    710.000000
# 50%    2.020110e+07  2020.000000     7.000000  202011.000000    834.000000
# 75%    2.022070e+07  2022.000000    10.000000  202207.000000    834.000000
# max    2.023120e+07  2023.000000    52.000000  202312.000000    834.000000
#
#        PartnerCode  Partner2Code        CmdCode    AggrLevel  MosCode  ...  \
# count  1819.000000        1819.0    1819.000000  1819.000000   1819.0  ...
# mean    507.269379           0.0  378883.565146     5.056625      0.0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1819 entries, 0 to 1818
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TypeCode                  1819 non-null   object
#  1   FreqCode                  1819 non-null   object
#  2   RefPeriodId               1819 non-null   int64
#  3   RefYear                   1819 non-null   int64
#  4   RefMonth                  1819 non-null   int64
#  5   Period                    1819 non-null   int64
#  6   ReporterCode              1819 non-null   int64
#  7   ReporterISO               1819 non-null   object
#  8   ReporterDesc              1819 non-null   object
#  9   FlowCode                  1819 non-null   object
#  10  FlowDesc                  1819 non-null   object
#  11  PartnerCode               1819 non-null   int64
#  12  PartnerISO                1819 non-null   object
# ...

# %% [markdown]
# Removing unnecessary Columns

# %%
newdf = df[df['QtyUnitCode'] != -1]
newdf.head()
# Out:
#    TypeCode FreqCode  RefPeriodId  RefYear  RefMonth  Period  ReporterCode  \
# 2         C        M     20170101     2017         1  201701           710
# 5         C        M     20170101     2017         1  201701           710
# 6         C        M     20170101     2017         1  201701           710
# 7         C        M     20170101     2017         1  201701           710
# 11        C        M     20170201     2017         2  201702           710
#
#    ReporterISO  ReporterDesc FlowCode  ...   NetWgt  IsNetWgtEstimated  \
# 2          ZAF  South Africa        X  ...  8819.51              False
# 5          ZAF  South Africa        X  ...  8820.51              False
# 6          ZAF  South Africa        X  ...     1.00              False
# 7          ZAF  South Africa        X  ...  8819.51              False
# 11         ZAF  South Africa        X  ...  6110.60              False
#
#    GrossWgt IsGrossWgtEstimated  Cifvalue      Fobvalue  PrimaryValue  \
# ...

# %%
trudf = newdf.drop(columns=[
    'TypeCode', 'FreqCode', 'RefMonth', 'Period', 'ReporterCode', 'ReporterISO',
    'FlowCode', 'FlowDesc', 'PartnerCode', 'PartnerISO', 'Partner2Code', 'Partner2ISO',
    'ClassificationCode', 'ClassificationSearchCode', 'CmdDesc', 'CustomsCode',
    'CustomsDesc', 'MosCode', 'MotCode', 'MotDesc', 'NetWgt', 'IsNetWgtEstimated',
    'GrossWgt', 'IsGrossWgtEstimated', 'Cifvalue', 'Fobvalue', 'LegacyEstimationFlag',
    'IsOriginalClassification'
])

trudf
# Out:
#       RefPeriodId  RefYear             ReporterDesc           PartnerDesc  \
# 2        20170101     2017             South Africa            Areas, nes
# 5        20170101     2017             South Africa                 World
# 6        20170101     2017             South Africa               Namibia
# 7        20170101     2017             South Africa            Areas, nes
# 11       20170201     2017             South Africa            Areas, nes
# ...           ...      ...                      ...                   ...
# 1775     20231001     2023  United Rep. of Tanzania  United Arab Emirates
# 1780     20231001     2023  United Rep. of Tanzania           Switzerland
# 1781     20231001     2023  United Rep. of Tanzania  United Arab Emirates
# 1791     20231101     2023  United Rep. of Tanzania  United Arab Emirates
# 1799     20231101     2023  United Rep. of Tanzania  United Arab Emirates
#
#      Partner2Desc  CmdCode  AggrLevel  IsLeaf  QtyUnitCode QtyUnitAbbr  \
# ...
